# %% [markdown]
# ### Objects for storage and data
# #### How can the steps from Lab 1 be consolidated ?

# %%
from classes.Storage import Storage
from classes.MysqlStorage import MysqlStorage
from classes.CsvStorage import CsvStorage
import config
import inspect
import requests
import pandas as pd

# %% [markdown]
# ### Encapsulating data storage processes

# %% [markdown]
# What are the proceses typically used around storing data?

# %%
print(inspect.getsource(Storage))
# Out:
# class Storage :
#
# 	def __init__(self, name) :
# 		self.name = name
#
# 	# store passed dataframe object as table <name>
# 	def put(self, df, name) :
# 		assert False, "Storage.put(): needs implementation"
#
# 	# return requested query from storage in a dataframe
# 	def get(self, query_string) :
# 		assert False, 'Storage.get(): needs implementation'

# %%
print(inspect.getsource(CsvStorage))
# Out:
# class CsvStorage(Storage) :
#
# 	# setup database connection to mysql unless otherwise specified
# 	def __init__(self) :
# 		super().__init__('csvstorage')
#
#
# 	# store passed dataframe object as table <name>
# 	# NOTE - put overwrites by default
# 	def put(self, df, name) :
# 		try:
# 			df.to_csv(name + ".csv", Index=False)
# 		except Exception as ex:
# 			print("Storage.put failed")
# 			print(ex)
#
# 	# return requested query from storage in a dataframe
# 	def get(self, query_string) :
# 		try:
# 			df = pd.read_csv(query_string + ".csv")
# 		except Exception as ex:
# 			print("Storage.get failed")
# 			print(ex)
# 			return pd.DataFrame()
# 		return df

# %%
print(inspect.getsource(MysqlStorage))
# Out:
# class MysqlStorage(Storage) :
#
# 	# setup database connection to mysql unless otherwise specified
# 	def __init__(self, connPre='mysql+pymysql://') :
# 		connectStr = connPre + config.DB_USER + ":" + config.DB_PASS + "@" + config.DB_HOST +  "/" + config.DB_NAME
# 		#print(connectStr)
# 		try:
# 			self.db_engine = create_engine(connectStr)
# 		except Exception as ex:
# 			print("Storage object failed to initialize")
# 			print(ex)
# 			self.db_engine = -1
#
# 	# store passed dataframe object as table <name>
# 	# NOTE - put overwrites by default
# 	def put(self, df, name) :
# 		try:
# 			df.to_sql(name, self.db_engine, if_exists='replace')
# 		except Exception as ex:
# 			print("Storage.put failed")
# 			print(ex)
#
# 	# return requested query from storage in a dataframe
# 	def get(self, query_string) :
# 		try:
# 			df = pd.read_sql('select * from ' + query_string, self.db_engine, index_col='index')
# 		except Exception as ex:
# 			print("Storage.get failed")
# 			print(ex)
# 			return pd.DataFrame()
# 		return df

# %% [markdown]
# Notice that both Storage implementations:
#     1. Overwrite existing data
#     2. get/put an entire tables/dataframes

# %%
store_mysql = MysqlStorage()

# %%
sql_test = store_mysql.get('test')

# %%
sql_test.head()
# Out:
#        FacilityAdaAccess                                FacilityDescription  \
# index
# 0                    NaN  <h2>Overview</h2>Wildwood  Recreation  Site  i...
# 1                    NaN  <p>This  small  rustic  campground  is  locate...
# 2                    NaN  <h2>Overview</h2>Whispering  Falls  Campground...
# 3                    NaN  <p>The  Resort  is  situated  on  the  shores ...
# 4                    NaN  <p>Lost  Lake  Campground  is  adjacent  to  H...
#
#                                       FacilityDirections FacilityEmail  \
# index
# 0      Wildwood  Recreation  Site  is  located  39  m...          None
# 1      <p><u>From  Prineville ,  Oregon</u>:</p><p>Tr...          None
# 2      8.3  miles  southeast  of  Detroit ,  Oregon: ...          None
# 3      <p><u>From  Portland ,  OR</u>  Lost  Lake  Re...          None
# 4      <p>From  McKenzie  Bridge ,  OR ,  follow  Hig...          None
#
#        FacilityID  FacilityLatitude  FacilityLongitude FacilityMapURL  \
# index
# 0          234075         45.356111        -121.986667           None
# 1          236929         44.483882        -120.336554           None
# 2          251470         44.687792        -122.009353           None
# 3          235897         45.500800        -121.816410           None
# 4          244288         44.429277        -121.912475           None
#
#                         FacilityName FacilityPhone FacilityReservationURL  \
# index
# 0         WILDWOOD  RECREATION  SITE  503-622-3696                   None
# 1               Wildwood  Campground          None                   None
# 2      WHISPERING  FALLS  CAMPGROUND  503-854-3366                   None
# 3                 Lost  Lake  Resort          None                   None
# 4             Lost  Lake  Campground          None                   None
#
#       FacilityTypeDescription FacilityUseFeeDescription Keywords  \
# index
# 0                     Camping                      None     None
# 1                        None                      None     None
# 2                     Camping                      None     None
# 3                        None                      None     None
# 4                        None                      None     None
#
#       LastUpdatedDate  LegacyFacilityID OrgFacilityID StayLimit
# index
# 0          2016-05-12           74082.0      AN374082      None
# 1          2016-05-09               NaN         38780      None
# 2          2016-05-12          127540.0      AN427540      None
# 3          2016-05-09               NaN         53230      None
# 4          2016-05-09               NaN         13362      None

# %%
store_csv = CsvStorage()

# %%
store_csv.name
# Out:
# 'csvstorage'

# %%
csv_test = store_csv.get('test')
csv_test.head()
# Out:
#   FacilityAdaAccess                                FacilityDescription  \
# 0               NaN  <h2>Overview</h2>Wildwood  Recreation  Site  i...
# 1               NaN  <p>This  small  rustic  campground  is  locate...
# 2               NaN  <h2>Overview</h2>Whispering  Falls  Campground...
# 3               NaN  <p>The  Resort  is  situated  on  the  shores ...
# 4               NaN  <p>Lost  Lake  Campground  is  adjacent  to  H...
#
#                                   FacilityDirections  FacilityEmail  \
# 0  Wildwood  Recreation  Site  is  located  39  m...            NaN
# 1  <p><u>From  Prineville ,  Oregon</u>:</p><p>Tr...            NaN
# 2  8.3  miles  southeast  of  Detroit ,  Oregon: ...            NaN
# 3  <p><u>From  Portland ,  OR</u>  Lost  Lake  Re...            NaN
# 4  <p>From  McKenzie  Bridge ,  OR ,  follow  Hig...            NaN
#
#    FacilityID  FacilityLatitude  FacilityLongitude  FacilityMapURL  \
# 0      234075         45.356111        -121.986667             NaN
# 1      236929         44.483882        -120.336554             NaN
# 2      251470         44.687792        -122.009353             NaN
# 3      235897         45.500800        -121.816410             NaN
# 4      244288         44.429277        -121.912475             NaN
#
#                     FacilityName FacilityPhone  FacilityReservationURL  \
# 0     WILDWOOD  RECREATION  SITE  503-622-3696                     NaN
# 1           Wildwood  Campground           NaN                     NaN
# 2  WHISPERING  FALLS  CAMPGROUND  503-854-3366                     NaN
# 3             Lost  Lake  Resort           NaN                     NaN
# 4         Lost  Lake  Campground           NaN                     NaN
#
#   FacilityTypeDescription  FacilityUseFeeDescription  Keywords  \
# 0                 Camping                        NaN       NaN
# 1                     NaN                        NaN       NaN
# 2                 Camping                        NaN       NaN
# 3                     NaN                        NaN       NaN
# 4                     NaN                        NaN       NaN
#
#   LastUpdatedDate  LegacyFacilityID OrgFacilityID  StayLimit
# 0      2016-05-12           74082.0      AN374082        NaN
# 1      2016-05-09               NaN       38780.0        NaN
# 2      2016-05-12          127540.0      AN427540        NaN
# 3      2016-05-09               NaN       53230.0        NaN
# 4      2016-05-09               NaN       13362.0        NaN

# %% [markdown]
# ### Encapsulating the data extraction process

# %%
from classes.Data import Data
from classes.RidbData import RidbData
from classes.RidbDataLive import RidbDataLive

# %%
print(inspect.getsource(Data))
# Out:
# class Data():
#
# 	def __init__(self, name):
# 		self.name = name
# 		self.df = pd.DataFrame()
#
# 	def extract(self):
# 		assert False, "Data.extract must be defined"

# %% [markdown]
# Recall from Lab 1:

# %%
ridb_facilities_url = "https://ridb.recreation.gov/api/v1/facilities"
camping_params = params=dict(activity_id=9, apiKey = config.RIDB_API_KEY,\
                             latitude=45.4977712, longitude=-121.8211673, radius=15)
response = requests.get(ridb_facilities_url,camping_params)

# %%
print(inspect.getsource(RidbData))
# Out:
# class RidbData(Data):
#
# 	# RIDB API specific information
# 	activity_dict = dict(camping=9, hiking=14)
# 	ridb_endpoint = 'https://ridb.recreation.gov/api/v1'
# 	endpoint = ridb_endpoint + "/facilities"
# 	url_params = dict(apiKey = config.RIDB_API_KEY)
#
# 	# storage param is expected to be of type classes.Storage
# 	def __init__(self, name, activity, dict_params, storage):
# 		self.df = pd.DataFrame()
# 		try:
# 			self.activity_id = self.activity_dict[activity]
# 		except Exception as ex:
# 			print("RidbData.__init__(): cannot find activity: " + activity)
# 			print("Activity options are " + self.activity_dict.keys)
# 			print(ex)
# 			return
#
# 		# update the URL params to include the RIDB Key, activity_id, and input dict_params
# 		self.url_params.update(dict(activity_id = self.activity_id))
# 		self.url_params.update(dict_params)
# 		self.storage = storage
# 		self.name = name
#
# 	def clean(self) :
# 		self.df = self.df.replace('', np.nan)
# 		self.df = self.df.dropna(subset=['FacilityLatitude','FacilityLongitude'])
# 		if 'GEOJSON.COORDINATES' in self.df.columns :
# 			self.df = self.df.drop(['GEOJSON.COORDINATES'], axis=1)
# 		if 'GEOJSON.TYPE' in self.df.columns:
# 			self.df = self.df.drop(['GEOJSON.TYPE'], axis=1)
#
# 		# drop duplicates
# 		self.df = Utilities.dedupe_by_distance(self.df, 1, 'FacilityLatitude', 'FacilityLongitude', 'LastUpdatedDate')
#
#
# 	def extract(self):
# 		try :
# 			request_url = "http://" + config.LAMP_IP + '/ridb_mock.json'
# 			self.df = pd.read_json(request_url)
#
# 		except Exception as ex:
# 			print("RidbData.extract(): unable to get request " + self.endpoint)
# 			print("with params: " + str(self.url_params))
# 			print(ex)
# 			self.df = pd.DataFrame()
# 			return
#
# 		# clean up data after extraction
# 		self.clean()
#
# 	def put(self):
# 		if (self.df.empty) :
# 			print("RidbData.put(): dataframe is empty, run get() or extract()")
# 			return
# 		self.storage.put(self.df, self.name)
#
# 	def get(self) :
# 		self.df = self.storage.get(self.name)

# %%
print(inspect.getsource(RidbDataLive))
# Out:
# class RidbDataLive(RidbData) :
#
# 	def extract(self):
# 		try:
# 			response = requests.get(url=self.endpoint,params=self.url_params)
#
# 		except Exception as ex:
# 			print("RidbDataLive.extract(): unable to get request " + self.endpoint)
# 			print("with params: " + str(self.url_params))
# 			print(ex)
# 			self.df = pd.DataFrame()
# 			return
#
# 		try :
# 			data = json.loads(response.text)
# 			self.df = json_normalize(data['RECDATA'])
#
#
# 		except Exception as ex:
# 			print("RidbData.extract(): unable to read response")
# 			print(ex)
#
# 		self.clean()

# %%
dest_params = dict(latitude=45.4977712, longitude=-121.8211673, radius=15)
ridb_camping = RidbData("ridb_camping", "camping", dest_params, store_mysql)
ridb_camping_live = RidbDataLive("ridb_camping", "camping", dest_params, store_mysql)

# %%
ridb_camping.df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
ridb_camping.extract()
ridb_camping_live.extract()

# %%
ridb_camping.df.head()
# Out:
#   FacilityAdaAccess                                FacilityDescription  \
# 0               NaN  <h2>Overview</h2>Wildwood  Recreation  Site  i...
# 1               NaN  <p>This  small  rustic  campground  is  locate...
# 2               NaN  <h2>Overview</h2>Whispering  Falls  Campground...
# 3               NaN  <p>The  Resort  is  situated  on  the  shores ...
# 4               NaN  <p>Lost  Lake  Campground  is  adjacent  to  H...
#
#                                   FacilityDirections  FacilityEmail  \
# 0  Wildwood  Recreation  Site  is  located  39  m...            NaN
# 1  <p><u>From  Prineville ,  Oregon</u>:</p><p>Tr...            NaN
# 2  8.3  miles  southeast  of  Detroit ,  Oregon: ...            NaN
# 3  <p><u>From  Portland ,  OR</u>  Lost  Lake  Re...            NaN
# 4  <p>From  McKenzie  Bridge ,  OR ,  follow  Hig...            NaN
#
#    FacilityID  FacilityLatitude  FacilityLongitude  FacilityMapURL  \
# 0      234075         45.356111        -121.986667             NaN
# 1      236929         44.483882        -120.336554             NaN
# 2      251470         44.687792        -122.009353             NaN
# 3      235897         45.500800        -121.816410             NaN
# 4      244288         44.429277        -121.912475             NaN
#
#                     FacilityName FacilityPhone  FacilityReservationURL  \
# 0     WILDWOOD  RECREATION  SITE  503-622-3696                     NaN
# 1           Wildwood  Campground           NaN                     NaN
# 2  WHISPERING  FALLS  CAMPGROUND  503-854-3366                     NaN
# 3             Lost  Lake  Resort           NaN                     NaN
# 4         Lost  Lake  Campground           NaN                     NaN
#
#   FacilityTypeDescription  FacilityUseFeeDescription  Keywords  \
# 0                 Camping                        NaN       NaN
# 1                     NaN                        NaN       NaN
# 2                 Camping                        NaN       NaN
# 3                     NaN                        NaN       NaN
# 4                     NaN                        NaN       NaN
#
#   LastUpdatedDate  LegacyFacilityID OrgFacilityID  StayLimit
# 0      2016-05-12           74082.0      AN374082        NaN
# 1      2016-05-09               NaN         38780        NaN
# 2      2016-05-12          127540.0      AN427540        NaN
# 3      2016-05-09               NaN         53230        NaN
# 4      2016-05-09               NaN         13362        NaN

# %%
ridb_camping_live.df.head()
# Out:
#   FacilityAdaAccess                                FacilityDescription  \
# 0               NaN  <h2>Overview</h2>Riley Campground is an equest...
# 1               NaN  <h2>Overview</h2>Still Creek Campground lies i...
# 2               NaN  <h2>Overview</h2>Tollgate Campground is one of...
# 3               NaN  <h2>Overview</h2>The Camp Creek Campground sit...
# 4              True  <h2>Overview</h2>Lost Creek Campground is a fu...
#
#                                   FacilityDirections  FacilityEmail  \
# 0  From Sandy, travel Highway 26 for 18 miles to ...            NaN
# 1  From Portland, travel east on Highway 26 to Go...            NaN
# 2  From Portland, travel southeast on Highway 26 ...            NaN
# 3  From Portland, travel east on Highway 26 for a...            NaN
# 4  From Portland, follow Highway 26 for 18 miles ...            NaN
#
#    FacilityID  FacilityLatitude  FacilityLongitude  FacilityMapURL  \
# 0      232834         45.381389        -121.859444             NaN
# 1      232835         45.295833        -121.735556             NaN
# 2      232836         45.321944        -121.905278             NaN
# 3      232837         45.303056        -121.864722             NaN
# 4      232838         45.381944        -121.834444             NaN
#
#              FacilityName FacilityPhone  FacilityReservationURL  \
# 0  RILEY HORSE CAMPGROUND  541-328-0909                     NaN
# 1             STILL CREEK  541-328-0909                     NaN
# 2                TOLLGATE  541-328-0909                     NaN
# 3              CAMP CREEK  541-328-0909                     NaN
# 4              LOST CREEK  541-328-0909                     NaN
#
#   FacilityTypeDescription  FacilityUseFeeDescription  Keywords  \
# 0                 Camping                        NaN       NaN
# 1                 Camping                        NaN       NaN
# 2                 Camping                        NaN       NaN
# 3                 Camping                        NaN       NaN
# 4                 Camping                        NaN       NaN
#
#   LastUpdatedDate  LegacyFacilityID OrgFacilityID  StayLimit
# 0      2016-05-26           71617.0      AN371617        NaN
# 1      2016-05-26           71618.0      AN371618        NaN
# 2      2016-05-26           71619.0      AN371619        NaN
# 3      2016-05-26           71620.0      AN371620        NaN
# 4      2016-05-26           71621.0      AN371621        NaN

# %% [markdown]
# You can use the RidbData object to retrieve other types of facility info, like hiking! ()

# %%
ridb_hiking_live = RidbDataLive("ridb_hiking", "hiking", dest_params, store_mysql)

# %%
ridb_hiking_live.extract()

# %%
ridb_hiking_live.df.head()
# Out:
#   FacilityAdaAccess                                FacilityDescription  \
# 0               NaN  <h2>Overview</h2>Riley Campground is an equest...
# 1               NaN  <h2>Overview</h2>Still Creek Campground lies i...
# 2               NaN  <h2>Overview</h2>Tollgate Campground is one of...
# 3               NaN  <h2>Overview</h2>The Camp Creek Campground sit...
# 4              True  <h2>Overview</h2>Lost Creek Campground is a fu...
#
#                                   FacilityDirections  FacilityEmail  \
# 0  From Sandy, travel Highway 26 for 18 miles to ...            NaN
# 1  From Portland, travel east on Highway 26 to Go...            NaN
# 2  From Portland, travel southeast on Highway 26 ...            NaN
# 3  From Portland, travel east on Highway 26 for a...            NaN
# 4  From Portland, follow Highway 26 for 18 miles ...            NaN
#
#    FacilityID  FacilityLatitude  FacilityLongitude  FacilityMapURL  \
# 0      232834         45.381389        -121.859444             NaN
# 1      232835         45.295833        -121.735556             NaN
# 2      232836         45.321944        -121.905278             NaN
# 3      232837         45.303056        -121.864722             NaN
# 4      232838         45.381944        -121.834444             NaN
#
#              FacilityName FacilityPhone  FacilityReservationURL  \
# 0  RILEY HORSE CAMPGROUND  541-328-0909                     NaN
# 1             STILL CREEK  541-328-0909                     NaN
# 2                TOLLGATE  541-328-0909                     NaN
# 3              CAMP CREEK  541-328-0909                     NaN
# 4              LOST CREEK  541-328-0909                     NaN
#
#   FacilityTypeDescription  FacilityUseFeeDescription  Keywords  \
# 0                 Camping                        NaN       NaN
# 1                 Camping                        NaN       NaN
# 2                 Camping                        NaN       NaN
# 3                 Camping                        NaN       NaN
# 4                 Camping                        NaN       NaN
#
#   LastUpdatedDate  LegacyFacilityID OrgFacilityID  StayLimit
# 0      2016-05-26           71617.0      AN371617        NaN
# 1      2016-05-26           71618.0      AN371618        NaN
# 2      2016-05-26           71619.0      AN371619        NaN
# 3      2016-05-26           71620.0      AN371620        NaN
# 4      2016-05-26           71621.0      AN371621        NaN

# %%
ridb_camping.put()

# %%
ridb_hiking_live.put()

# %%
ridb_camping.name
# Out:
# 'ridb_camping'
