# %%
import requests	
from bs4 import BeautifulSoup
import re
import pandas as pd
import os
from sqlalchemy import create_engine
import config
from unidecode import unidecode
from camping import camping_data
from camping import storage

# %%
campgrounds = pd.read_csv('../data/usfs_sites.csv')

# %%
store = storage.Storage()

# %%
def extract_cg_info(campgrounds) :
    df_cg = pd.DataFrame()
    for index, campground in campgrounds.iterrows():
        latitude = longitude = elevation = site_id = numsites = conditions = ""
        fees = openseason = usage = water = restroom = status = ""
        site_url = "http://" + config.LAMP_IP + "/" + campground['url']
        print(campground['facilityname'] + '\t' + site_url)
        try :
            cg_req = requests.get(site_url)
            cg_soup = BeautifulSoup(cg_req.text, 'lxml')
        except Exception as ex :
            print('couldnt get site_url ' + site_url)
            print(ex)
            continue

        # get area status if available
        try :
            for strong_tag in cg_soup.find_all('strong'):
                if ('Area Status' in unidecode(strong_tag.text)):
                    status = unidecode(strong_tag.next_sibling).strip()
        except Exception:
            print('couldnt get area status')


        print("getting location")
        # get lat, long, altitude
        try :
            lat = cg_soup.find_all('div', text=re.compile('Latitude'))
            div = [row.next_sibling.next_sibling for row in lat]
            latitude  = div[0].text.strip()

            lng = cg_soup.find_all('div', text=re.compile('Longitude'))
            div = [row.next_sibling.next_sibling for row in lng]
            longitude  = div[0].text.strip()

            el = cg_soup.find_all('div', text=re.compile('Elevation'))
            div = [row.next_sibling.next_sibling for row in el]
            elevation  = div[0].text.strip()

            # get site usage, type, num sites, site info

        except Exception:
            print('couldnt get location info')

        # table[0] is the basic info table

        try :
            tables = cg_soup.find_all('div', {'class': 'tablecolor'})
        except Exception:
            print('couldnt get tables')

        try :
            print(len(tables))
            rows = tables[0].find_all('tr')
            for row in rows:
                
                if row.th.text == 'Reservations:':
                    reservations = unidecode(row.td.text).strip()
                if row.th.text == 'Open Season:':
                    openseason = unidecode(row.td.text).strip()
                if row.th.text == 'Current Conditions:':
                    print(unidecode(row.td.text))
                    conditions = unidecode(row.td.text).strip()
                if row.th.text == 'Water:':
                    water = unidecode(row.td.text).strip()
                if row.th.text == 'Restroom:':
                    restroom = unidecode(row.td.text).strip()
        except Exception as ex:
            print('couldnt get basic campground info')
            print(ex)

        # table 1 is the campground info
        try:
            rows = tables[1].find_all('tr')

            for row in rows:
                if row.td.text == 'Reservation Info':
                    reserveinfo = unidecode(row.td.next_sibling.text).strip()
                if row.td.text == 'No. of Sites':
                    numsites = unidecode(row.td.next_sibling.text).strip()
        except Exception:
            print('couldnt get campsite availability info')
        
        # assemble into DataFrame
        df_cg = df_cg.append(pd.DataFrame ({
            'latitude': [latitude],
            'longitude': [longitude],
            'elevation': [elevation],
            'facilityname' : [campground['facilityname']],
            'facilityurl' : [site_url],
            'status' : [status],
            'water' : [water],
            'restroom' : [restroom],
            'reservations': [reservations],
            'conditions': [conditions],
            'numsites': [numsites]
            }))
    return df_cg

# %%
test = extract_cg_info(campgrounds)
# Out:
# whispering falls campground	http://172.17.0.3/Willamette National Forest - Whispering Falls Campground.html
# getting location
# 5
# lost lake campground	http://172.17.0.3/Mt. Hood National Forest - Lost Lake Campground.html
# getting location
# 10
# OPEN
# lake harriet campground	http://172.17.0.3/Mt. Hood National Forest - Lake Harriet Campground_Day Use.html
# getting location
# 2
# kinnikinnick (laurance lake) campground	http://172.17.0.3/Mt. Hood National Forest - Kinnikinnick (Laurance Lake) Campground.html
# getting location
# 9
# OPEN
# fifteenmile campground	http://172.17.0.3/Mt. Hood National Forest - Fifteenmile Campground.html
# getting location
# 5
# No services provided.A  Pack in/Pack out.
# clear lake campground	http://172.17.0.3/Mt. Hood National Forest - Clear Lake Campground.html
# getting location
# 8
# CLOSED
# camp creek campground	http://172.17.0.3/Mt. Hood National Forest - Camp Creek Campground.html
# getting location
# 5
# badger lake campground	http://172.17.0.3/Mt. Hood National Forest - Badger Lake Campground.html
# getting location
# 9
# Campground not accessible due to snow
# eagle creek campground	http://172.17.0.3/Columbia River Gorge National Scenic Area - Eagle Creek Campground.html
# getting location
# 6
# Eagle Creek campgroundisA reservable starting December 1, 2015A for the 2016 seasonA at recreation.gov.A  Reservations can be made up to six months in advance.  Reservations must be made at least 48 hours in advance of planned stay.

# %%
test.shape
# Out:
# (9, 11)

# %%
test
# Out:
#                                           conditions  elevation  \
# 0                                                     2000 feet
# 0                                               OPEN       3200
# 0                                                          2000
# 0                                               OPEN       3000
# 0          No services provided.A  Pack in/Pack out.       4000
# 0                                             CLOSED       3600
# 0                                                          2200
# 0              Campground not accessible due to snow       4400
# 0  Eagle Creek campgroundisA reservable starting ...  200 - 200
#
#                               facilityname  \
# 0              whispering falls campground
# 0                     lost lake campground
# 0                  lake harriet campground
# 0  kinnikinnick (laurance lake) campground
# 0                   fifteenmile campground
# 0                    clear lake campground
# 0                    camp creek campground
# 0                   badger lake campground
# 0                   eagle creek campground
#
#                                          facilityurl           latitude  \
# 0  http://172.17.0.3/Willamette National Forest -...  44.68829400202167
# 0  http://172.17.0.3/Mt. Hood National Forest - L...           45.50080
# 0  http://172.17.0.3/Mt. Hood National Forest - L...          45.073611
# 0  http://172.17.0.3/Mt. Hood National Forest - K...           45.45748
# 0  http://172.17.0.3/Mt. Hood National Forest - F...            45.3505
# 0  http://172.17.0.3/Mt. Hood National Forest - C...           45.17945
# 0  http://172.17.0.3/Mt. Hood National Forest - C...          45.305236
# 0  http://172.17.0.3/Mt. Hood National Forest - B...           45.30496
# 0  http://172.17.0.3/Columbia River Gorge Nationa...          45.642244
#
#             longitude                           numsites  \
# 0  -122.0103430470687                                 16
# 0          -121.81641
# 0         -121.956944                  13 single site(s)
# 0          -121.66343  20 walk-in access only campsites.
# 0           -121.4729                   3 single site(s)
# 0          -121.69675
# 0         -121.867275
# 0          -121.55537                   4 single site(s)
# 0         -121.925284                                 17
#
#                                         reservations           restroom  \
# 0  Reserve online at www.recreation.gov or phone ...  Vault Toilets (3)
# 0  This site can be reserved by calling Toll Free...  Vault Toilet (18)
# 0  This site can be reserved by calling Toll Free...       Vault Toilet
# 0  This site can be reserved by calling Toll Free...   Vault Toilet (2)
# 0                                    No reservations   Vault Toilet (1)
# 0  This site can be reserved by calling Toll Free...       Vault Toilet
# 0  This site can be reserved by calling Toll Free...       Vault Toilet
# 0                                    No reservations   Vault Toilet (1)
# 0  Eagle Creek Campground sites can be reserved u...      Flush toilets
#
#    status                    water
# 0                              Yes
# 0    Open            Potable Water
# 0    Open            Potable Water
# 0    Open                       No
# 0    Open                       No
# 0  Closed            Potable Water
# 0  Closed            Potable Water
# 0    Open                       No
# 0    Open  Potable water available

# %%
test
# Out:
#                                            conditions  elevation  \
# 0                                                 NaN  2000 feet
# 1                                                OPEN       3200
# 2                                                 NaN       2000
# 3                                                OPEN       3000
# 4           No services provided.A  Pack in/Pack out.       4000
# 5                                              CLOSED       3600
# 6                                                 NaN       2200
# 7               Campground not accessible due to snow       4400
# 8   Eagle Creek campgroundisA reservable starting ...  200 - 200
# 9                                                 NaN  2000 feet
# 10                                               OPEN       3200
# 11                                                NaN       2000
# 12                                               OPEN       3000
# 13          No services provided.A  Pack in/Pack out.       4000
# 14                                             CLOSED       3600
# 15                                                NaN       2200
# 16              Campground not accessible due to snow       4400
# 17  Eagle Creek campgroundisA reservable starting ...  200 - 200
#
#                                facilityname  \
# 0               whispering falls campground
# 1                      lost lake campground
# 2                   lake harriet campground
# 3   kinnikinnick (laurance lake) campground
# 4                    fifteenmile campground
# 5                     clear lake campground
# 6                     camp creek campground
# 7                    badger lake campground
# 8                    eagle creek campground
# 9               whispering falls campground
# 10                     lost lake campground
# 11                  lake harriet campground
# 12  kinnikinnick (laurance lake) campground
# 13                   fifteenmile campground
# 14                    clear lake campground
# 15                    camp creek campground
# 16                   badger lake campground
# 17                   eagle creek campground
#
#                                           facilityurl   latitude   longitude  \
# 0   http://172.17.0.2/Willamette National Forest -...  44.688294 -122.010343
# 1   http://172.17.0.2/Mt. Hood National Forest - L...  45.500800 -121.816410
# 2   http://172.17.0.2/Mt. Hood National Forest - L...  45.073611 -121.956944
# 3   http://172.17.0.2/Mt. Hood National Forest - K...  45.457480 -121.663430
# 4   http://172.17.0.2/Mt. Hood National Forest - F...  45.350500 -121.472900
# 5   http://172.17.0.2/Mt. Hood National Forest - C...  45.179450 -121.696750
# 6   http://172.17.0.2/Mt. Hood National Forest - C...  45.305236 -121.867275
# 7   http://172.17.0.2/Mt. Hood National Forest - B...  45.304960 -121.555370
# 8   http://172.17.0.2/Columbia River Gorge Nationa...  45.642244 -121.925284
# 9   http://172.17.0.2/Willamette National Forest -...  44.688294 -122.010343
# 10  http://172.17.0.2/Mt. Hood National Forest - L...  45.500800 -121.816410
# 11  http://172.17.0.2/Mt. Hood National Forest - L...  45.073611 -121.956944
# 12  http://172.17.0.2/Mt. Hood National Forest - K...  45.457480 -121.663430
# 13  http://172.17.0.2/Mt. Hood National Forest - F...  45.350500 -121.472900
# 14  http://172.17.0.2/Mt. Hood National Forest - C...  45.179450 -121.696750
# 15  http://172.17.0.2/Mt. Hood National Forest - C...  45.305236 -121.867275
# 16  http://172.17.0.2/Mt. Hood National Forest - B...  45.304960 -121.555370
# 17  http://172.17.0.2/Columbia River Gorge Nationa...  45.642244 -121.925284
#
#                              numsites  \
# 0                                  16
# 1                                 NaN
# 2                   13 single site(s)
# 3   20 walk-in access only campsites.
# 4                    3 single site(s)
# 5                                 NaN
# 6                                 NaN
# 7                    4 single site(s)
# 8                                  17
# 9                                  16
# 10                                NaN
# 11                  13 single site(s)
# 12  20 walk-in access only campsites.
# 13                   3 single site(s)
# 14                                NaN
# 15                                NaN
# 16                   4 single site(s)
# 17                                 17
#
#                                          reservations           restroom  \
# 0   Reserve online at www.recreation.gov or phone ...  Vault Toilets (3)
# 1   This site can be reserved by calling Toll Free...  Vault Toilet (18)
# 2   This site can be reserved by calling Toll Free...       Vault Toilet
# 3   This site can be reserved by calling Toll Free...   Vault Toilet (2)
# 4                                     No reservations   Vault Toilet (1)
# 5   This site can be reserved by calling Toll Free...       Vault Toilet
# 6   This site can be reserved by calling Toll Free...       Vault Toilet
# 7                                     No reservations   Vault Toilet (1)
# 8   Eagle Creek Campground sites can be reserved u...      Flush toilets
# 9   Reserve online at www.recreation.gov or phone ...  Vault Toilets (3)
# 10  This site can be reserved by calling Toll Free...  Vault Toilet (18)
# 11  This site can be reserved by calling Toll Free...       Vault Toilet
# 12  This site can be reserved by calling Toll Free...   Vault Toilet (2)
# 13                                    No reservations   Vault Toilet (1)
# 14  This site can be reserved by calling Toll Free...       Vault Toilet
# 15  This site can be reserved by calling Toll Free...       Vault Toilet
# 16                                    No reservations   Vault Toilet (1)
# 17  Eagle Creek Campground sites can be reserved u...      Flush toilets
#
#     status                    water
# 0      NaN                      Yes
# 1     Open            Potable Water
# 2     Open            Potable Water
# 3     Open                       No
# 4     Open                       No
# 5   Closed            Potable Water
# 6   Closed            Potable Water
# 7     Open                       No
# 8     Open  Potable water available
# 9      NaN                      Yes
# 10    Open            Potable Water
# 11    Open            Potable Water
# 12    Open                       No
# 13    Open                       No
# 14  Closed            Potable Water
# 15  Closed            Potable Water
# 16    Open                       No
# 17    Open  Potable water available
